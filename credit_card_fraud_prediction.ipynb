# %%
import numpy as np
import pandas as pd

from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import accuracy_score

# %%
df= pd.read_csv("creditcard.csv")

# %%
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
df.shape
# Out:
# (284807, 31)

# %%
# checking missing values
df.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
# checking mathematical values
df["Class"].value_counts()
# Out:
# Class
# 0    284315
# 1       492
# Name: count, dtype: int64

# %% [markdown]
# ### Data is Highly Undistributed

# %%
# dividing data
legal= df[df.Class==0]
fraud= df[df.Class==1]

# %%
legal.shape
# Out:
# (284315, 31)

# %%
fraud.shape
# Out:
# (492, 31)

# %%
# checking mathematical values for legal cases
legal["Amount"].describe()
# Out:
# count    284315.000000
# mean         88.291022
# std         250.105092
# min           0.000000
# 25%           5.650000
# 50%          22.000000
# 75%          77.050000
# max       25691.160000
# Name: Amount, dtype: float64

# %%
# checking mathematical values for fraud cases
fraud["Amount"].describe()
# Out:
# count     492.000000
# mean      122.211321
# std       256.683288
# min         0.000000
# 25%         1.000000
# 50%         9.250000
# 75%       105.890000
# max      2125.870000
# Name: Amount, dtype: float64

# %%
# checking number of fraud cases
fraud.shape[0]
# Out:
# 492

# %% [markdown]
# ### Taking 492 legal cases randomly to match fraud cases and making dataframe an equally distributed dataframe

# %%
legal_cases= legal.sample(492)

# %%
legal_cases["Amount"].value_counts()
# Out:
# Amount
# 1.00      21
# 1.98       8
# 9.99       6
# 0.89       5
# 0.99       5
#           ..
# 44.80      1
# 410.55     1
# 11.01      1
# 25.30      1
# 25.17      1
# Name: count, Length: 383, dtype: int64

# %%
# merging into new dataframe
new_df= pd.concat([legal_cases, fraud], axis=0)

# %%
new_df.sample(5)
# Out:
#             Time         V1         V2         V3        V4         V5  \
# 15451    26833.0 -20.532751  12.373989 -23.009003  6.144821 -15.587296
# 8312     11092.0   0.378275   3.914797  -5.726872  6.094141   1.698875
# 208619  137197.0  -1.314859   0.546792  -3.053410 -0.334218   0.201128
# 6283      7400.0  -1.412596  -0.332206   2.097674 -2.592999  -2.012421
# 154668  102480.0  -1.929597   4.066413  -4.865184  5.898602  -0.552493
#
#               V6         V7         V8        V9  ...       V21       V22  \
# 15451  -4.384491 -15.939003  13.696416 -3.948455  ...  1.754608 -1.466115
# 8312   -2.807314  -0.591118  -0.123496 -2.530713  ...  0.149896 -0.601967
# 208619 -1.009267   2.482278  -0.287806  0.031881  ...  0.187060  1.516613
# 6283    0.809680   1.481785  -0.143080  2.652359  ...  0.089729  0.823502
# 154668 -1.555962  -3.833623   0.679512 -3.463765  ...  1.137212  0.674245
#
#              V23       V24       V25       V26       V27       V28  Amount  \
# ...

# %%
new_df.shape
# Out:
# (984, 31)

# %%
# labeling new dataframe as input and output data
X= new_df.drop(["Class"], axis=1)
Y=new_df["Class"]

# %%
# splitting data into test and train data
X_train, X_test, Y_train, Y_test= train_test_split(X,Y, stratify=Y, test_size=0.2, random_state=2)

# %%
lr=LogisticRegression()
lr.fit(X_train, Y_train)
# Out:
# C:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
# checking accuracy for training data
y_pred_train=lr.predict(X_train)

# %%
accuracy_score(Y_train, y_pred_train)
# Out:
# 0.9440914866581956

# %%
np.mean(cross_val_score(lr, X, Y, cv= 20))
# Out:
# C:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
# ...

# %%
# accuracy for test data
y_pred_test= lr.predict(X_test)

# %%
accuracy_score(Y_test, y_pred_test)
# Out:
# 0.9137055837563451
